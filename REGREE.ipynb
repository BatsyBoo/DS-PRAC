# %% [markdown]
# <a href="https://colab.research.google.com/github/BatsyBoo/DS-PRAC/blob/main/REGREE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as ns

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# df=pd.read_csv(r"P:\2026 GATE\padhai\ml\programs\temperatures.csv")

from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['temperatures.csv']))
# Out:
#      <input type="file" id="files-f7f2c8dd-25e1-47cc-80c3-9c91db64ca58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7f2c8dd-25e1-47cc-80c3-9c91db64ca58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
x =df['YEAR'].values.reshape(-1, 1)
y =df['ANNUAL']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=16)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.figure(figsize=(16,9),facecolor='lightyellow')
# plt.set_facecolor('lavender')
plt.title('Temperature of India')
plt.xlabel('Year')
plt.ylabel('Temperature of India')
plt.scatter(x, y, color='red', label='Data Points')
plt.plot(x, y_pred, color='green', linewidth=2, label='Regression Line')
plt.legend()
plt.show()

# fig, ax = plt.subplots(figsize=(16,9))

# # Set background colors
# fig.set_facecolor('lightyellow')    # outer figure background
# ax.set_facecolor('black')        # inner plot area background

# # Add your plot
# ax.set_title('Temperature of India')
# ax.set_xlabel('Year')
# ax.set_ylabel('Temperature of India')

# ax.scatter(x, y, color='red', label='Data Points')
# ax.plot(x, y_pred, color='green', linewidth=2, label='Regression Line')

# ax.legend()
# plt.show()

# %%
threshold=df["ANNUAL"].median()
# now binary classification
y_class=(df["ANNUAL"]>threshold).astype(int)
print(y_calass)
# Out:
# 0
